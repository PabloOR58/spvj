# %%
# !pip install matplotlib
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.7 MB 3.7 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.3/9.7 MB 3.2 MB/s eta 0:00:03
#    ------- -------------------------------- 1.8/9.7 MB 3.2 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.6/9.7 MB 3.1 MB/s eta 0:00:03
#    ------------ --------------------------- 3.1/9.7 MB 3.1 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.9/9.7 MB 3.1 MB/s eta 0:00:02
#    ------------------ --------------------- 4.5/9.7 MB 3.1 MB/s eta 0:00:02
#    --------------------- ------------------ 5.2/9.7 MB 3.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.8/9.7 MB 3.1 MB/s eta 0:00:02
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("listado_juegos.csv", engine="python", on_bad_lines="skip")
top100 = df.head(100)

plt.figure(figsize=(6,4))
plt.bar(top100["Juego"], top100["Jugadores"])

plt.xticks(rotation=45)
plt.show()
